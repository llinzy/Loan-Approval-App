# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from scipy.stats import kstest
from scipy.stats import norm
from sklearn.pipeline import Pipeline
#model modules
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import GradientBoostingClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
orig_data=pd.read_csv("datasets/loan_data.csv")

# %%
orig_data.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.08                         2.0           504
# 2                 0.44                         3.0           635
# 3                 0.44                         2.0           675
# 4                 0.53                         4.0           586
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1
# 1                            Yes            0
# 2                             No            1
# 3                             No            1
# 4                             No            1

# %%
orig_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
#  12  previous_loan_defaults_on_file  45000 non-null  object
#  13  loan_status                     45000 non-null  int64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 4.8+ MB

# %%
numeric_cols={}
nonnumeric_cols={}
for i in orig_data.columns:
    if isinstance(orig_data[i][0], str):
        labeler=LabelEncoder()
        labels=labeler.fit_transform(orig_data[i])
        nonnumeric_cols[i]=labels
    else:
        numeric_cols[i]=orig_data[i]

# %%
dataset=pd.concat([pd.DataFrame.from_dict(nonnumeric_cols), pd.DataFrame.from_dict(numeric_cols)], axis=1)

# %%
#inspect multicollinearity
dataset.corr().where(abs(dataset.corr())>.79)
# Out:
#                                 person_gender  person_education  \
# person_gender                             1.0               NaN
# person_education                          NaN               1.0
# person_home_ownership                     NaN               NaN
# loan_intent                               NaN               NaN
# previous_loan_defaults_on_file            NaN               NaN
# person_age                                NaN               NaN
# person_income                             NaN               NaN
# person_emp_exp                            NaN               NaN
# loan_amnt                                 NaN               NaN
# loan_int_rate                             NaN               NaN
# loan_percent_income                       NaN               NaN
# cb_person_cred_hist_length                NaN               NaN
# credit_score                              NaN               NaN
# loan_status                               NaN               NaN
#
#                                 person_home_ownership  loan_intent  \
# person_gender                                     NaN          NaN
# person_education                                  NaN          NaN
# person_home_ownership                             1.0          NaN
# loan_intent                                       NaN          1.0
# previous_loan_defaults_on_file                    NaN          NaN
# person_age                                        NaN          NaN
# person_income                                     NaN          NaN
# person_emp_exp                                    NaN          NaN
# loan_amnt                                         NaN          NaN
# loan_int_rate                                     NaN          NaN
# loan_percent_income                               NaN          NaN
# cb_person_cred_hist_length                        NaN          NaN
# credit_score                                      NaN          NaN
# loan_status                                       NaN          NaN
#
#                                 previous_loan_defaults_on_file  person_age  \
# person_gender                                              NaN         NaN
# person_education                                           NaN         NaN
# person_home_ownership                                      NaN         NaN
# loan_intent                                                NaN         NaN
# previous_loan_defaults_on_file                             1.0         NaN
# person_age                                                 NaN    1.000000
# person_income                                              NaN         NaN
# person_emp_exp                                             NaN    0.954412
# loan_amnt                                                  NaN         NaN
# loan_int_rate                                              NaN         NaN
# loan_percent_income                                        NaN         NaN
# cb_person_cred_hist_length                                 NaN    0.861985
# credit_score                                               NaN         NaN
# loan_status                                                NaN         NaN
#
#                                 person_income  person_emp_exp  loan_amnt  \
# person_gender                             NaN             NaN        NaN
# person_education                          NaN             NaN        NaN
# person_home_ownership                     NaN             NaN        NaN
# loan_intent                               NaN             NaN        NaN
# previous_loan_defaults_on_file            NaN             NaN        NaN
# person_age                                NaN        0.954412        NaN
# person_income                             1.0             NaN        NaN
# person_emp_exp                            NaN        1.000000        NaN
# loan_amnt                                 NaN             NaN        1.0
# loan_int_rate                             NaN             NaN        NaN
# loan_percent_income                       NaN             NaN        NaN
# cb_person_cred_hist_length                NaN        0.824272        NaN
# credit_score                              NaN             NaN        NaN
# loan_status                               NaN             NaN        NaN
#
#                                 loan_int_rate  loan_percent_income  \
# person_gender                             NaN                  NaN
# person_education                          NaN                  NaN
# person_home_ownership                     NaN                  NaN
# loan_intent                               NaN                  NaN
# previous_loan_defaults_on_file            NaN                  NaN
# person_age                                NaN                  NaN
# person_income                             NaN                  NaN
# person_emp_exp                            NaN                  NaN
# loan_amnt                                 NaN                  NaN
# loan_int_rate                             1.0                  NaN
# loan_percent_income                       NaN                  1.0
# cb_person_cred_hist_length                NaN                  NaN
# credit_score                              NaN                  NaN
# loan_status                               NaN                  NaN
#
#                                 cb_person_cred_hist_length  credit_score  \
# person_gender                                          NaN           NaN
# person_education                                       NaN           NaN
# person_home_ownership                                  NaN           NaN
# loan_intent                                            NaN           NaN
# previous_loan_defaults_on_file                         NaN           NaN
# person_age                                        0.861985           NaN
# person_income                                          NaN           NaN
# person_emp_exp                                    0.824272           NaN
# loan_amnt                                              NaN           NaN
# loan_int_rate                                          NaN           NaN
# loan_percent_income                                    NaN           NaN
# cb_person_cred_hist_length                        1.000000           NaN
# credit_score                                           NaN           1.0
# loan_status                                            NaN           NaN
#
#                                 loan_status
# person_gender                           NaN
# person_education                        NaN
# person_home_ownership                   NaN
# loan_intent                             NaN
# previous_loan_defaults_on_file          NaN
# person_age                              NaN
# person_income                           NaN
# person_emp_exp                          NaN
# loan_amnt                               NaN
# loan_int_rate                           NaN
# loan_percent_income                     NaN
# cb_person_cred_hist_length              NaN
# credit_score                            NaN
# loan_status                             1.0

# %%
dataset.corr()
# Out:
#                                 person_gender  person_education  \
# person_gender                        1.000000         -0.002267
# person_education                    -0.002267          1.000000
# person_home_ownership               -0.001172         -0.000290
# loan_intent                         -0.003107          0.004356
# previous_loan_defaults_on_file       0.000704         -0.002669
# person_age                           0.017528         -0.014649
# person_income                        0.010173          0.000331
# person_emp_exp                       0.015078         -0.012034
# loan_amnt                            0.010647         -0.002441
# loan_int_rate                        0.003662          0.000336
# loan_percent_income                 -0.000367         -0.006984
# cb_person_cred_hist_length           0.011999         -0.014576
# credit_score                        -0.000223          0.012498
# loan_status                         -0.000561         -0.001747
#
#                                 person_home_ownership  loan_intent  \
# person_gender                               -0.001172    -0.003107
# person_education                            -0.000290     0.004356
# person_home_ownership                        1.000000     0.001828
# loan_intent                                  0.001828     1.000000
# previous_loan_defaults_on_file              -0.125974     0.038469
# person_age                                  -0.039008     0.032005
# person_income                               -0.219870     0.008639
# person_emp_exp                              -0.035884     0.031230
# loan_amnt                                   -0.150243    -0.001068
# loan_int_rate                                0.130437    -0.005372
# loan_percent_income                          0.148933     0.003269
# cb_person_cred_hist_length                  -0.029549     0.030912
# credit_score                                -0.006421     0.016244
# loan_status                                  0.233842    -0.072158
#
#                                 previous_loan_defaults_on_file  person_age  \
# person_gender                                         0.000704    0.017528
# person_education                                     -0.002669   -0.014649
# person_home_ownership                                -0.125974   -0.039008
# loan_intent                                           0.038469    0.032005
# previous_loan_defaults_on_file                        1.000000   -0.025917
# person_age                                           -0.025917    1.000000
# person_income                                         0.061483    0.193698
# person_emp_exp                                       -0.029231    0.954412
# loan_amnt                                            -0.059009    0.050750
# loan_int_rate                                        -0.181800    0.013402
# loan_percent_income                                  -0.203252   -0.043299
# cb_person_cred_hist_length                           -0.022640    0.861985
# credit_score                                         -0.183005    0.178432
# loan_status                                          -0.543096   -0.021476
#
#                                 person_income  person_emp_exp  loan_amnt  \
# person_gender                        0.010173        0.015078   0.010647
# person_education                     0.000331       -0.012034  -0.002441
# person_home_ownership               -0.219870       -0.035884  -0.150243
# loan_intent                          0.008639        0.031230  -0.001068
# previous_loan_defaults_on_file       0.061483       -0.029231  -0.059009
# person_age                           0.193698        0.954412   0.050750
# person_income                        1.000000        0.185987   0.242290
# person_emp_exp                       0.185987        1.000000   0.044589
# loan_amnt                            0.242290        0.044589   1.000000
# loan_int_rate                        0.001510        0.016631   0.146093
# loan_percent_income                 -0.234177       -0.039862   0.593011
# cb_person_cred_hist_length           0.124316        0.824272   0.042969
# credit_score                         0.035919        0.186196   0.009074
# loan_status                         -0.135808       -0.020481   0.107714
#
#                                 loan_int_rate  loan_percent_income  \
# person_gender                        0.003662            -0.000367
# person_education                     0.000336            -0.006984
# person_home_ownership                0.130437             0.148933
# loan_intent                         -0.005372             0.003269
# previous_loan_defaults_on_file      -0.181800            -0.203252
# person_age                           0.013402            -0.043299
# person_income                        0.001510            -0.234177
# person_emp_exp                       0.016631            -0.039862
# loan_amnt                            0.146093             0.593011
# loan_int_rate                        1.000000             0.125209
# loan_percent_income                  0.125209             1.000000
# cb_person_cred_hist_length           0.018008            -0.031868
# credit_score                         0.011498            -0.011483
# loan_status                          0.332005             0.384880
#
#                                 cb_person_cred_hist_length  credit_score  \
# person_gender                                     0.011999     -0.000223
# person_education                                 -0.014576      0.012498
# person_home_ownership                            -0.029549     -0.006421
# loan_intent                                       0.030912      0.016244
# previous_loan_defaults_on_file                   -0.022640     -0.183005
# person_age                                        0.861985      0.178432
# person_income                                     0.124316      0.035919
# person_emp_exp                                    0.824272      0.186196
# loan_amnt                                         0.042969      0.009074
# loan_int_rate                                     0.018008      0.011498
# loan_percent_income                              -0.031868     -0.011483
# cb_person_cred_hist_length                        1.000000      0.155204
# credit_score                                      0.155204      1.000000
# loan_status                                      -0.014851     -0.007647
#
#                                 loan_status
# person_gender                     -0.000561
# person_education                  -0.001747
# person_home_ownership              0.233842
# loan_intent                       -0.072158
# previous_loan_defaults_on_file    -0.543096
# person_age                        -0.021476
# person_income                     -0.135808
# person_emp_exp                    -0.020481
# loan_amnt                          0.107714
# loan_int_rate                      0.332005
# loan_percent_income                0.384880
# cb_person_cred_hist_length        -0.014851
# credit_score                      -0.007647
# loan_status                        1.000000

# %%
dataset=dataset.drop(["person_emp_exp", "cb_person_cred_hist_length"], axis=1)

# %%
#test for normality
for i in dataset.columns:
    stat, p = kstest(dataset[i], 'norm', args=(dataset[i].mean(), dataset[i].std()))
    print(f'Statistic={stat:.3f}, p-value={p:.3f}')
# Out:
# Statistic=0.368, p-value=0.000
# Statistic=0.258, p-value=0.000
# Statistic=0.338, p-value=0.000
# Statistic=0.174, p-value=0.000
# Statistic=0.345, p-value=0.000
# Statistic=0.155, p-value=0.000
# Statistic=0.214, p-value=0.000
# Statistic=0.135, p-value=0.000
# Statistic=0.067, p-value=0.000
# Statistic=0.106, p-value=0.000
# Statistic=0.059, p-value=0.000
# Statistic=0.481, p-value=0.000

# %%
#Standardize X values
scaler=StandardScaler()
scaled_dataset=pd.DataFrame(scaler.fit_transform(dataset))
scaled_dataset.columns=list(dataset.columns)

# %%
X=scaled_dataset.drop("loan_status", axis=1)
y=dataset["loan_status"]

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=.30, random_state=42)

# %%
def classifier_scoring (X_train, X_test, y_train, y_test):
	classifiers = [
	RandomForestClassifier(random_state=42),
	RidgeClassifier(random_state=42),
	GradientBoostingClassifier(random_state=42),
	LogisticRegression(random_state=42)
	]
	
	scores=[]
	for i in classifiers:
		pipe = Pipeline(steps=[('classifier', i)])
		pi=pipe.fit(X_train, y_train)
		scores.append(cross_val_score(pi, X_test, y_test, cv=5,
		verbose=True).mean())
	return ["Random Forest Score {}".format(scores[0]), "RidgeClassifier Score {}".format(scores[1]), "Gradient Boosting Score {}".format(scores[2]),
	"Logistic Regression Score {}".format(scores[3])]

# %%
#get best classifiers by score results. 
#raise exception if number of classifiers do not match number of score results
try:
	score_results=classifier_scoring(X_train, X_test, y_train, y_test)
	print("Best Scoring Classifier: {}".format(sorted(score_results, reverse=False)[0]))
except IndexError:
	print("No Results. Number of classifers need to match number of scores to return!")
else:
	pass
# Out:
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.1s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
# Best Scoring Classifier: Gradient Boosting Score 0.9191851851851853
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    6.0s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished

# %%
gb=GradientBoostingClassifier(n_estimators=200, max_depth=3, min_samples_split=2,
                              min_samples_leaf=1, subsample=.9, random_state=42)

# %%
gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(n_estimators=200, random_state=42, subsample=0.9)

# %%
predictions=gb.predict(X_test)

# %%
accuracy_score(predictions, y_test)
# Out:
# 0.9262222222222222

# %%
import joblib
joblib.dump(gb, 'loandata.pkl')
# Out:
# ['loandata.pkl']
